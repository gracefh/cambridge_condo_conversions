# %% [markdown]
# # 1. Check if all datasets have the same columns

# %%
import pandas as pd

# %%
base_file_path = "all_data/ASSESSING_PropertyDatabase"

def check_columns_consistency(base_file_path, start_year=2015, end_year=2024):
    columns_dict = {}  # To store columns of each dataset by year
    inconsistencies = []  # To store any inconsistencies found

    # Load each dataset and store its columns
    for year in range(start_year, end_year + 1):
        file_path = f'{base_file_path}_FY{year}.csv'
        df = pd.read_csv(file_path)
        columns_dict[year] = set(df.columns)
#         print(columns_dict)

    # Compare columns of the first dataset with the rest
    base_columns = columns_dict[start_year]
    for year, columns in columns_dict.items():
        if columns != base_columns:
            differences = base_columns.symmetric_difference(columns)
            inconsistencies.append((year, differences))

    # Prepare the summary report
    if not inconsistencies:
        summary = "All datasets from {} to {} have the same columns.".format(start_year, end_year)
    else:
        summary = "Found inconsistencies in dataset columns for the following years:\n"
        for year, diff in inconsistencies:
            summary += f"Year {year}: Different columns - {diff}\n"

    return summary


summary = check_columns_consistency(base_file_path, 2015, 2024)
print(summary)
# Out:
# Found inconsistencies in dataset columns for the following years:
# Year 2016: Different columns - {'Owner_City', 'Owner_Address', 'Owner_Name', 'Owner_Address2', 'Owner_Zip', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2017: Different columns - {'Owner_City', 'Owner_Address', 'Owner_Name', 'Owner_Address2', 'Owner_Zip', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2018: Different columns - {'Owner_City', 'Owner_Address', 'Owner_Name', 'Owner_Address2', 'Owner_Zip', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2019: Different columns - {'Owner_City', 'PropertyTaxAmount', 'Owner_Address', 'Owner_Name', 'Owner_Address2', 'Owner_Zip', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2020: Different columns - {'Owner_City', 'PropertyTaxAmount', 'Exterior_Occupancy', 'Owner_Address', 'Map/Lot', 'BookPage', 'Book/Page', 'Owner_Name', 'Exterior_occupancy', 'Owner_Address2', 'Owner_Zip', 'MapLot', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2021: Different columns - {'Owner_City', 'Exterior_Occupancy', 'Owner_Address', 'Map/Lot', 'BookPage', 'Book/Page', 'Owner_Name', 'Exterior_occupancy', 'Owner_Address2', 'Owner_Zip', 'MapLot', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2022: Different columns - {'Owner_City', 'PropertyTaxAmount', 'Exterior_Occupancy', 'Owner_Address', 'Map/Lot', 'BookPage', 'Book/Page', 'Owner_Name', 'Exterior_occupancy', 'Owner_Address2', 'Owner_Zip', 'MapLot', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2023: Different columns - {'Owner_City', 'PropertyTaxAmount', 'Exterior_Occupancy', 'Owner_Address', 'Map/Lot', 'BookPage', 'Book/Page', 'Owner_Name', 'Exterior_occupancy', 'Owner_Address2', 'Owner_Zip', 'MapLot', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}
# Year 2024: Different columns - {'Owner_City', 'PropertyTaxAmount', 'Exterior_Occupancy', 'Owner_Address', 'Map/Lot', 'BookPage', 'Book/Page', 'Owner_Name', 'Exterior_occupancy', 'Owner_Address2', 'Owner_Zip', 'MapLot', 'Owner_State', 'Owners', 'Owner_CoOwnerName'}

# %%
## load each datasets into a dataframe, data_yyyy

def load_datasets():
    for year in range(2015, 2025):  # From 2015 to 2023 inclusive
        file_name = f"all_data/ASSESSING_PropertyDatabase_FY{year}.csv"  # Adjust the path as needed
        variable_name = f"data_{year}"
        # Dynamically construct the command to read the CSV and assign it to a variable
        command = f"{variable_name} = pd.read_csv('{file_name}')"
        exec(command, globals())

# Call the function to load the datasets
load_datasets()

# After calling load_datasets(), variables data_2015, data_2016, ..., data_2024 will be available

# %%
data_2015["GISID"]
# Out:
# 0             ="7-18"
# 1             ="7-19"
# 2             ="7-29"
# 3             ="7-31"
# 4             ="7-34"
#              ...
# 28798       ="1A-179"
# 28799       ="93-137"
# 28800       ="23-157"
# 28801       ="75-171"
# 28802    ="267.1-277"
# Name: GISID, Length: 28803, dtype: object

# %% [markdown]
# ### Clean GISID entry of data_2015

# %%
# Function to clean the GISID column
def clean_gisid(value):
    # Remove unwanted characters
    cleaned_value = value.replace('="', '').replace('"', '')
    # Extract numbers and reformat
    numbers = cleaned_value.split('-')
    if len(numbers) == 2:
        try:
            # Convert to float and format back to string to normalize the number format
            num1 = int(numbers[0])
            num2 = int(numbers[1])
            return f"{num1}-{num2}"
        except ValueError:
            # If conversion fails, return the original cleaned string
            return cleaned_value
    else:
        # Return the original cleaned string if it doesn't contain exactly two numbers
        return cleaned_value

# Apply the cleaning function to the GISID column
data_2015['GISID'] = data_2015['GISID'].apply(clean_gisid)

data_2015["GISID"]
# Out:
# 0             7-18
# 1             7-19
# 2             7-29
# 3             7-31
# 4             7-34
#            ...
# 28798       1A-179
# 28799       93-137
# 28800       23-157
# 28801       75-171
# 28802    267.1-277
# Name: GISID, Length: 28803, dtype: object

# %% [markdown]
# ## Resolving column inconsistencies across datasets
#
# For example:
#
# Dataset 2015 - 2019 has column name "Exterior_occupancy"
#
# Dataset 2020 - 2024 has column name "Exterior_Occupancy"

# %%
# Sets of different columns for each year
columns_2016 = {'Owner_Zip', 'Owner_Address2', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Owner_State', 'Owner_City'}
columns_2017 = {'Owner_Zip', 'Owner_Address2', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Owner_State', 'Owner_City'}
columns_2018 = {'Owner_Zip', 'Owner_Address2', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Owner_State', 'Owner_City'}
columns_2019 = {'Owner_Zip', 'Owner_Address2', 'PropertyTaxAmount', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Owner_State', 'Owner_City'}
columns_2020 = {'Book/Page', 'Exterior_Occupancy', 'BookPage', 'Owner_Zip', 'Owner_Address2', 'PropertyTaxAmount', 'Exterior_occupancy', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Map/Lot', 'Owner_State', 'MapLot', 'Owner_City'}
columns_2021 = {'Book/Page', 'Exterior_Occupancy', 'BookPage', 'Owner_Zip', 'Owner_Address2', 'Exterior_occupancy', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Map/Lot', 'Owner_State', 'MapLot', 'Owner_City'}
columns_2022 = {'Book/Page', 'Exterior_Occupancy', 'BookPage', 'Owner_Zip', 'Owner_Address2', 'PropertyTaxAmount', 'Exterior_occupancy', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Map/Lot', 'Owner_State', 'MapLot', 'Owner_City'}
columns_2023 = {'Book/Page', 'Exterior_Occupancy', 'BookPage', 'Owner_Zip', 'Owner_Address2', 'PropertyTaxAmount', 'Exterior_occupancy', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Map/Lot', 'Owner_State', 'MapLot', 'Owner_City'}
columns_2024 = {'Book/Page', 'Exterior_Occupancy', 'BookPage', 'Owner_Zip', 'Owner_Address2', 'PropertyTaxAmount', 'Exterior_occupancy', 'Owner_Name', 'Owner_CoOwnerName', 'Owners', 'Owner_Address', 'Map/Lot', 'Owner_State', 'MapLot', 'Owner_City'}

# Combine all sets to get a set of unique column names
unique_columns = set.union(columns_2016, columns_2017, columns_2018, columns_2019, columns_2020, columns_2021, columns_2022, columns_2023, columns_2024)
unique_columns
# Out:
# {'Book/Page',
#  'BookPage',
#  'Exterior_Occupancy',
#  'Exterior_occupancy',
#  'Map/Lot',
#  'MapLot',
#  'Owner_Address',
#  'Owner_Address2',
#  'Owner_City',
#  'Owner_CoOwnerName',
#  'Owner_Name',
#  'Owner_State',
#  'Owner_Zip',
#  'Owners',
#  'PropertyTaxAmount'}

# %% [markdown]
# ### "Exterior_occupancy -> Exterior_Occupancy"

# %%
### We rename 2015-2019 column name to be "Exterior_Occupancy"

for year in range(2015, 2020):  # 2020 is not included, so it goes from 2015 to 2019
    # Construct the variable name
    variable_name = f"data_{year}"
    # Access the DataFrame using globals() and rename the column
    globals()[variable_name].rename(columns={'Exterior_occupancy': 'Exterior_Occupancy'}, inplace=True)

# %%
## we remove "Exterior_occupancy"
unique_columns.remove("Exterior_occupancy")
unique_columns.remove('Exterior_Occupancy')
unique_columns
# Out:
# {'Book/Page',
#  'BookPage',
#  'Map/Lot',
#  'MapLot',
#  'Owner_Address',
#  'Owner_Address2',
#  'Owner_City',
#  'Owner_CoOwnerName',
#  'Owner_Name',
#  'Owner_State',
#  'Owner_Zip',
#  'Owners',
#  'PropertyTaxAmount'}

# %% [markdown]
# ## Checking which dataset has / misses which columns

# %%
# List of dataset variables
datasets = [data_2015, data_2016, data_2017, data_2018, data_2019, data_2020, data_2021, data_2022, data_2023, data_2024]

# Initialize a list to store the presence of unique columns in each dataset
column_presence = []

# Iterate over each dataset and check for column presence
for i, dataset in enumerate(datasets, start=2015):
    column_presence.append({column: (column in dataset.columns) for column in unique_columns})

# Convert the list of dictionaries to a DataFrame and then transpose it
presence_df = pd.DataFrame(column_presence, index=[f'data_{year}' for year in range(2015, 2025)]).T.sort_index()
presence_df
# Out:
#                    data_2015  data_2016  data_2017  data_2018  data_2019  \
# Book/Page               True       True       True       True       True
# BookPage               False      False      False      False      False
# Map/Lot                 True       True       True       True       True
# MapLot                 False      False      False      False      False
# Owner_Address          False       True       True       True       True
# Owner_Address2         False       True       True       True       True
# Owner_City             False       True       True       True       True
# Owner_CoOwnerName      False       True       True       True       True
# Owner_Name             False       True       True       True       True
# Owner_State            False       True       True       True       True
# Owner_Zip              False       True       True       True       True
# Owners                  True      False      False      False      False
# PropertyTaxAmount      False      False      False      False       True
#
#                    data_2020  data_2021  data_2022  data_2023  data_2024
# Book/Page              False      False      False      False      False
# BookPage                True       True       True       True       True
# Map/Lot                False      False      False      False      False
# MapLot                  True       True       True       True       True
# Owner_Address           True       True       True       True       True
# Owner_Address2          True       True       True       True       True
# Owner_City              True       True       True       True       True
# Owner_CoOwnerName       True       True       True       True       True
# Owner_Name              True       True       True       True       True
# Owner_State             True       True       True       True       True
# Owner_Zip               True       True       True       True       True
# Owners                 False      False      False      False      False
# PropertyTaxAmount       True      False       True       True       True

# %% [markdown]
# ### "Book/Page" -> "BookPage"

# %%
### We rename 2015-2019 column name to be "BookPage"

for year in range(2015, 2020):  # 2020 is not included, so it goes from 2015 to 2019
    # Construct the variable name
    variable_name = f"data_{year}"
    # Access the DataFrame using globals() and rename the column
    globals()[variable_name].rename(columns={'Book/Page': 'BookPage'}, inplace=True)

# %%
## we remove "BookPage" and "Book/Page"
unique_columns.remove("Book/Page")
unique_columns.remove('BookPage')
unique_columns
# Out:
# {'Map/Lot',
#  'MapLot',
#  'Owner_Address',
#  'Owner_Address2',
#  'Owner_City',
#  'Owner_CoOwnerName',
#  'Owner_Name',
#  'Owner_State',
#  'Owner_Zip',
#  'Owners',
#  'PropertyTaxAmount'}

# %% [markdown]
# ### "Map/Log" -> "MapLot"

# %%
### We rename 2015-2019 column name to be "MapLot"

for year in range(2015, 2020):  # 2020 is not included, so it goes from 2015 to 2019
    # Construct the variable name
    variable_name = f"data_{year}"
    # Access the DataFrame using globals() and rename the column
    globals()[variable_name].rename(columns={'Map/Lot': 'MapLot'}, inplace=True)

# %%
unique_columns.remove("Map/Lot")
unique_columns.remove('MapLot')
unique_columns
# Out:
# {'Owner_Address',
#  'Owner_Address2',
#  'Owner_City',
#  'Owner_CoOwnerName',
#  'Owner_Name',
#  'Owner_State',
#  'Owner_Zip',
#  'Owners',
#  'PropertyTaxAmount'}

# %% [markdown]
# ### "Owner_name" & "Owner_CoOwnerName" -> "Owners"
#
# Looking closer at the data, we notice that 2015 has one column that listed all owners, whereas other years it was listed as "Owner_name" and "Owner_CoOwnerName"
#
# Here we combine "Owner_name" and "Owner_CoOwnerName" for year 2016 - 2024 to "Owners"

# %%
data_2015["Owners"]

# %%
data_2020["Owner_Name"]

# %%
for year in range(2016, 2025):  # Loop from 2016 to 2024
    # Construct the variable name for the dataset
    dataset_var = f'data_{year}'
    
    # Access the DataFrame using globals()
    df = globals().get(dataset_var)
    
    if df is not None:
        # Check if both columns exist in the DataFrame
        if 'Owner_Name' in df.columns and 'Owner_CoOwnerName' in df.columns:
            # Combine the columns into a new column, handling NaN values appropriately
            # we also know for a fact from our table above that owner_name and owner_CoOwnerName always appear together in the datasets
            # so we are not writing any exception handling
            df['Owners'] = df.apply(lambda x: f"{x['Owner_Name']}, {x['Owner_CoOwnerName']}" if pd.notna(x['Owner_CoOwnerName']) else x['Owner_Name'], axis=1)
            # Drop the original columns
            df.drop(columns=['Owner_Name', 'Owner_CoOwnerName'], inplace=True)

# %%
## we remove "['Owner_Name', 'Owner_CoOwnerName']"
unique_columns.remove('Owner_Name')
unique_columns.remove('Owner_CoOwnerName')
unique_columns.remove('Owners')

# %%
unique_columns
# Out:
# {'Owner_Address',
#  'Owner_Address2',
#  'Owner_City',
#  'Owner_State',
#  'Owner_Zip',
#  'PropertyTaxAmount'}

# %% [markdown]
# ### Adding cols to datasets

# %%
# List of columns to add
new_columns = ['Owner_Address', 'Owner_Address2', 'Owner_City', 'Owner_State', 'Owner_Zip', 'PropertyTaxAmount']

# Initialize the columns with 'NA'
for column in new_columns:
    data_2015[column] = 'NA'

# %%
data_2016["PropertyTaxAmount"] = 'NA'
data_2017["PropertyTaxAmount"] = 'NA'
data_2018["PropertyTaxAmount"] = 'NA'
data_2021["PropertyTaxAmount"] = 'NA'

# %%
def check_columns_consistency(data_frames):
    # Get the column names for the first DataFrame
    reference_columns = set(data_frames[0].columns)
    
    # Iterate through the rest of the DataFrames and compare their column names
    for i, df in enumerate(data_frames[1:], start=2016):
        if set(df.columns) != reference_columns:
            print(f"Columns in data_{i} are not consistent with data_2015")
            return False
    
    print("All datasets have the same columns.")
    return True

# Create a list of your DataFrames for 2015 to 2024
data_frames = [globals()[f"data_{year}"] for year in range(2015, 2025)]

# Call the function to check column consistency
check_columns_consistency(data_frames)
# Out:
# All datasets have the same columns.
# True

# %% [markdown]
# # 2. Detect Condo Conversion

# %% [markdown]
# Let's start by counting how many entries are associated with each address in year 2015 (prior) and year 2016 (post)

# %%
count_prior = data_2015.groupby('Address').size()

# %%
count_post = data_2016.groupby('Address').size()

# %%
# we assume that an address has been converted into a condo, 
# if the previous year (2015) only has one address record
# but the post year (2016) has more than one entry associted with the same address
# then we consider it a condo conversion
condo_conversion_addresses = count_post[(count_post > 1) & (count_prior == 1)].index.tolist()
condo_conversion_addresses
# Out:
# ['10 Ellery St',
#  '12 Avon Pl',
#  '12 Rindgefield St',
#  '133-135 Fresh Pond Pkwy',
#  '139 Charles St',
#  '15 Oak St',
#  '150 Cambridgepark Dr',
#  '155 Webster Ave',
#  '159 Fayerweather St',
#  '17 Cambridge Ter',
#  '17 Copley St',
#  '18 White St',
#  '18-20 Whittemore Ave',
#  '198 Sherman St',
#  '20 Vincent St',
#  '207 Prospect St',
#  '21 Sciarappa St',
#  '24-26 Whittemore Ave',
#  '2579 Massachusetts Ave',
#  '280 Walden St',
#  '30-32 Whittemore Ave',
#  '32 Church St',
#  '346 Putnam Ave',
#  '354 Rindge Ave',
#  '37-39 Mt Pleasant St',
#  '51 Cedar St',
#  '55-59 Cushing St',
#  '676-694 Huron Ave',
#  '7 Temple St',
#  '7 Trowbridge Pl',
#  '700 Main St',
#  '9 Harding St',
#  '93 Kirkland St',
#  '99 Brookline St']

# %%
# we filter the original data_2015 & data_2016 for just the addresses of condo conversions
condo_conversion_data_prior = data_2015[data_2015['Address'].isin(condo_conversion_addresses)]
condo_conversion_data_post = data_2016[data_2016['Address'].isin(condo_conversion_addresses)]

# %%
# let's do a test: address 10 Ellery St is detected as a condo_conversion
# there's only one entry (PID) in prior year (2015)
condo_conversion_data_prior[condo_conversion_data_prior["Address"] == "10 Ellery St"]
# Out:
#        PID    GISID  BldgNum       Address Unit  StateClassCode PropertyClass  \
# 8212  8053  116-119        1  10 Ellery St  NaN             104   TWO-FAM-RES
#
#       Zoning      MapLot  LandArea  ...  Parking_Covered Parking_Garage  \
# 8212  ="C-1"  ="116-119"      6082  ...              0.0            NaN
#
#       UnfinishedBasementGross  FinishedBasementGross  Owner_Address  \
# 8212                     1154                    0.0             NA
#
#       Owner_Address2  Owner_City Owner_State Owner_Zip  PropertyTaxAmount
# 8212              NA          NA          NA        NA                 NA
#
# [1 rows x 60 columns]

# %%
# whereas in post_year (2016), there are 4 entries (PIDs)
condo_conversion_data_post[condo_conversion_data_post["Address"] == "10 Ellery St"]
# Out:
#           PID    GISID  BldgNum       Address Unit  StateClassCode  \
# 8207     8053  116-119        1  10 Ellery St  NaN             199
# 8208     8053  116-119        2  10 Ellery St  NaN             199
# 28859  192375  116-119        1  10 Ellery St    A             102
# 28860  192376  116-119        1  10 Ellery St    B             102
#
#       PropertyClass Zoning     MapLot  LandArea  ...  \
# 8207     CONDO-BLDG    C-1    116-119      6082  ...
# 8208     CONDO-BLDG    C-1    116-119      6082  ...
# 28859   CONDOMINIUM    NaN  116-119-A         0  ...
# 28860   CONDOMINIUM    NaN  116-119-B         0  ...
#
#        Condition_InteriorCondition Condition_OverallCondition  \
# 8207                           NaN                        NaN
# 8208                           NaN                        NaN
# 28859                          NaN                  Excellent
# 28860                          NaN                  Excellent
#
#        Condition_OverallGrade  Parking_Open  Parking_Covered  Parking_Garage  \
# 8207                      NaN           0.0              0.0             NaN
# 8208                      NaN           0.0              0.0             NaN
# 28859               Very Good           1.0              0.0             0.0
# 28860               Very Good           1.0              0.0             0.0
#
#        UnfinishedBasementGross FinishedBasementGross  \
# 8207                       720                   0.0
# 8208                         0                 663.0
# 28859                        0                 686.0
# 28860                        0                 693.0
#
#                                                   Owners  PropertyTaxAmount
# 8207                                10 ELLERY STREET LLC                 NA
# 8208                                10 ELLERY STREET LLC                 NA
# 28859                       THE MARIE WU & RENEE WU LLC,                 NA
# 28860  10 ELLERY STREET LLC,, C/O SIEGEL, ADAM & REBE...                 NA
#
# [4 rows x 60 columns]

# %%
# count the number of condos in the post year
condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
condo_conversion_data_post
# Out:
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/2269369886.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
#           PID    GISID  BldgNum          Address Unit  StateClassCode  \
# 656       690    17-20        1   139 Charles St  NaN             199
# 920       958    22-55        1  21 Sciarappa St  NaN             199
# 2177     2167   36-185        1     9 Harding St  NaN             199
# 3014     3016    71-56        1      700 Main St  NaN             199
# 3015     3016    71-56        2      700 Main St  NaN             199
# ...       ...      ...      ...              ...  ...             ...
# 28859  192375  116-119        1     10 Ellery St    A             102
# 28860  192376  116-119        1     10 Ellery St    B             102
# 28874  192471  107-133        1      7 Temple St  NaN             957
# 28875  192471  107-133        2      7 Temple St  NaN             957
# 28876  192491   169-82        1     32 Church St  NaN             942
#
#                      PropertyClass  Zoning     MapLot  LandArea  ...  \
# 656                     CONDO-BLDG     C-1      17-20      2115  ...
# 920                     CONDO-BLDG     C-1      22-55      1679  ...
# 2177                    CONDO-BLDG     C-1     36-185      2938  ...
# 3014                    CONDO-BLDG      IB      71-56    138947  ...
# 3015                    CONDO-BLDG      IB      71-56    138947  ...
# ...                            ...     ...        ...       ...  ...
# 28859                  CONDOMINIUM     NaN  116-119-A         0  ...
# 28860                  CONDOMINIUM     NaN  116-119-B         0  ...
# 28874               Charitable Svc     O-3   107-133E     37068  ...
# 28875               Charitable Svc     O-3   107-133E     37068  ...
# 28876  Private College, University  BB-HSQ    169-82E      5072  ...
#
#        Condition_OverallCondition Condition_OverallGrade  Parking_Open  \
# 656                           NaN                    NaN           0.0
# 920                           NaN                    NaN           0.0
# 2177                          NaN                    NaN           0.0
# 3014                          NaN                    NaN           0.0
# 3015                          NaN                    NaN           0.0
# ...                           ...                    ...           ...
# 28859                   Excellent              Very Good           1.0
# 28860                   Excellent              Very Good           1.0
# 28874                        Good                   GOOD           NaN
# 28875                   Excellent                AVERAGE           NaN
# 28876                        Good              VERY-GOOD           NaN
#
#        Parking_Covered  Parking_Garage  UnfinishedBasementGross  \
# 656                0.0             NaN                        0
# 920                0.0             NaN                        0
# 2177               0.0             NaN                      918
# 3014               0.0             NaN                        0
# 3015               0.0             NaN                        0
# ...                ...             ...                      ...
# 28859              0.0             0.0                        0
# 28860              0.0             0.0                        0
# 28874              NaN             NaN                        0
# 28875              NaN             NaN                        0
# 28876              NaN             NaN                        0
#
#        FinishedBasementGross  \
# 656                    821.0
# 920                   1023.0
# 2177                     0.0
# 3014                     0.0
# 3015                     0.0
# ...                      ...
# 28859                  686.0
# 28860                  693.0
# 28874                    NaN
# 28875                    NaN
# 28876                    NaN
#
#                                                   Owners PropertyTaxAmount  \
# 656                               139 CHARLES STREET LLC                NA
# 920                                 SCIARAPPA STREET LLC                NA
# 2177                               9 HARDING STREET, LLC                NA
# 3014                            MIT 650 MAIN STREET, LLC                NA
# 3015                            MIT 650 MAIN STREET, LLC                NA
# ...                                                  ...               ...
# 28859                       THE MARIE WU & RENEE WU LLC,                NA
# 28860  10 ELLERY STREET LLC,, C/O SIEGEL, ADAM & REBE...                NA
# 28874        CAMBRIDGE YOUNG WOMEN, CHRISTIAN ASSOCIATES                NA
# 28875        CAMBRIDGE YOUNG WOMEN, CHRISTIAN ASSOCIATES                NA
# 28876  PRESIDENT & FELLOWS OF HARVARD, C/O HARVARD RE...                NA
#
#        num_condo_units
# 656                  3
# 920                  3
# 2177                 4
# 3014                 3
# 3015                 3
# ...                ...
# 28859                4
# 28860                4
# 28874                2
# 28875                2
# 28876                2
#
# [112 rows x 61 columns]

# %%
condo_conversion_data_post[condo_conversion_data_post["Address"] == "10 Ellery St"]["num_condo_units"]
# Out:
# 8207     4
# 8208     4
# 28859    4
# 28860    4
# Name: num_condo_units, dtype: int64

# %% [markdown]
# ### Keeping only one entry after calculating num_condo_units

# %%
# keeping only the first row of each address
condo_conversion_data_post = condo_conversion_data_post.drop_duplicates(subset='Address', keep='first')
condo_conversion_data_post
# Out:
#           PID      GISID  BldgNum                  Address Unit  \
# 656       690      17-20        1           139 Charles St  NaN
# 920       958      22-55        1          21 Sciarappa St  NaN
# 2177     2167     36-185        1             9 Harding St  NaN
# 28758                 WHITTEMORE STREET DEVELOPMENT LLC.                NA
# 28759                 WHITTEMORE STREET DEVELOPMENT LLC,                NA
# 28874        CAMBRIDGE YOUNG WOMEN, CHRISTIAN ASSOCIATES                NA
#
#        num_condo_units
# 656                  3
# 920                  3
# 2177                 4
# 3014                 3
# 3502                 2
# 3936                 2
# 5093                 4
# 7120                 4
# 8207                 4
# 10189                3
# 10935                2
# 12428                9
# 13502                2
# 15549                3
# 16149                2
# 16549                3
# 16773                3
# 17369                4
# 18080                3
# 19588                4
# 21292                4
# 21575                3
# 21725                3
# 21892                3
# 21925                4
# 22473                2
# 23189                4
# 23204                4
# 23312                2
# 23543                5
# 28757                3
# 28758                3
# 28759                3
# 28874                2
#
# [34 rows x 61 columns]

# %% [markdown]
# ### Add sufix to datasets

# %%
column_mapping = {}
for column in condo_conversion_data_prior.columns:
    if column != 'Address':
        column_mapping[column] = column + '_prior'

# Rename the columns using the mapping dictionary
condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
condo_conversion_data_prior
# Out:
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1405330687.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
#        PID_prior GISID_prior  BldgNum_prior                  Address  \
# 659          690       17-20              1           139 Charles St
# 923          958       22-55              1          21 Sciarappa St
# 2179        2167      36-185              1             9 Harding St
# 3021        3016       71-50              1              700 Main St
# 3507        3498       78-79              1          155 Webster Ave
# 3940        3891       83-25              1                15 Oak St
# 5097        4996       94-89              1          99 Brookline St
# 6845        6714     107-133              1              7 Temple St
# 7124        6984      109-42              1          207 Prospect St
# 8212        8053     116-119              1             10 Ellery St
# 10192      10028     127-152              1           346 Putnam Ave
# 10938      10750      135-14              1          7 Trowbridge Pl
# 12431      12205       152-7              1              18 White St
# 13506      13218      169-82              1             32 Church St
# 15556      15279      186-27              1   2579 Massachusetts Ave
# 16158      15875       192-9              1              51 Cedar St
# 16557      16257      194-70              1           198 Sherman St
# 16781      16472      196-91              1        12 Rindgefield St
# 17378      17071     201-101              1         17 Cambridge Ter
# 18091      17759      211-15              1               12 Avon Pl
# 19601      19223      228-31              1            280 Walden St
# 21305      20903       254-8              1         55-59 Cushing St
# 21588      21159      257-47              1        676-694 Huron Ave
# 21736      21305      259-17              1  133-135 Fresh Pond Pkwy
# 21903      21473      262-71              1      159 Fayerweather St
# 21936      21506      262-99              1             17 Copley St
# 22485      22007     146A-74              1           93 Kirkland St
# 23200      22689    201.5-16              1            20 Vincent St
# 23215      22705    201.5-28              1     37-39 Mt Pleasant St
# 23323      22828   267.4-317              1     150 Cambridgepark Dr
# 23560     184077     268B-41              1           354 Rindge Ave
# 28787     191920     188-146              1     30-32 Whittemore Ave
# 28788     191921     188-147              1     24-26 Whittemore Ave
# 28789     191922     188-148              1     18-20 Whittemore Ave
#
#       Unit_prior  StateClassCode_prior PropertyClass_prior Zoning_prior  \
# 659          NaN                   101        SNGL-FAM-RES       ="C-1"
# 923          NaN                   104         TWO-FAM-RES       ="C-1"
# 2179         NaN                   105        THREE-FM-RES       ="C-1"
# 3021         NaN                   406           HIGH-TECH        ="IB"
# 3507         NaN                   105        THREE-FM-RES       ="C-1"
# 15556                NA                NA              NA
# 16158                NA                NA              NA
# 16557                NA                NA              NA
# 16781                NA                NA              NA
# 17378                NA                NA              NA
# 18091                NA                NA              NA
# 19601                NA                NA              NA
# 21305                NA                NA              NA
# 21588                NA                NA              NA
# 21736                NA                NA              NA
# 21903                NA                NA              NA
# 21936                NA                NA              NA
# 22485                NA                NA              NA
# 23200                NA                NA              NA
# 23215                NA                NA              NA
# 23323                NA                NA              NA
# 23560                NA                NA              NA
# 28787                NA                NA              NA
# 28788                NA                NA              NA
# 28789                NA                NA              NA
#
#        PropertyTaxAmount_prior
# 659                         NA
# 923                         NA
# 2179                        NA
# 3021                        NA
# 3507                        NA
# 3940                        NA
# 5097                        NA
# 6845                        NA
# 7124                        NA
# 8212                        NA
# 10192                       NA
# 10938                       NA
# 12431                       NA
# 13506                       NA
# 15556                       NA
# 16158                       NA
# 16557                       NA
# 16781                       NA
# 17378                       NA
# 18091                       NA
# 19601                       NA
# 21305                       NA
# 21588                       NA
# 21736                       NA
# 21903                       NA
# 21936                       NA
# 22485                       NA
# 23200                       NA
# 23215                       NA
# 23323                       NA
# 23560                       NA
# 28787                       NA
# 28788                       NA
# 28789                       NA
#
# [34 rows x 60 columns]

# %%
column_mapping = {}
for column in condo_conversion_data_post.columns:
    if column != 'Address':
        column_mapping[column] = column + '_post'

# Rename the columns using the mapping dictionary
condo_conversion_data_post.rename(columns=column_mapping, inplace=True)
condo_conversion_data_post
# Out:
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/283116331.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post.rename(columns=column_mapping, inplace=True)
#        PID_post GISID_post  BldgNum_post                  Address Unit_post  \
# 656         690      17-20             1           139 Charles St       NaN
# 920         958      22-55             1          21 Sciarappa St       NaN
# 2177       2167     36-185             1             9 Harding St       NaN
# 3014       3016      71-56             1              700 Main St       NaN
# 3502       3498      78-79             1          155 Webster Ave       NaN
# 3936       3891      83-25             1                15 Oak St       NaN
# 5093       4996      94-89             1          99 Brookline St       NaN
# 7120       6984     109-42             1          207 Prospect St       NaN
# 8207       8053    116-119             1             10 Ellery St       NaN
# 10189     10028    127-152             1           346 Putnam Ave       NaN
# 10935     10750     135-14             1          7 Trowbridge Pl       NaN
# 12428     12205      152-7             1              18 White St       NaN
# 13502     13218     169-82             1             32 Church St       NaN
# 15549     15279     186-27             1   2579 Massachusetts Ave       NaN
# 16149     15875      192-9             1              51 Cedar St       NaN
# 16549     16257     194-70             1           198 Sherman St       NaN
# 16773     16472     196-91             1        12 Rindgefield St       NaN
# 17369     17071    201-101             1         17 Cambridge Ter       NaN
# 18080     17759     211-15             1               12 Avon Pl       NaN
# 19588     19223     228-31             1            280 Walden St       NaN
# 21292     20903      254-8             1         55-59 Cushing St       NaN
# 21575     21159     257-47             1        676-694 Huron Ave       NaN
# 21725     21305     259-17             1  133-135 Fresh Pond Pkwy       NaN
# 21892     21473     262-71             1      159 Fayerweather St       NaN
# 21925     21506     262-99             1             17 Copley St       NaN
# 22473     22007    146A-74             1           93 Kirkland St       NaN
# 23189     22689   201.5-16             1            20 Vincent St       NaN
# 23204     22705   201.5-28             1     37-39 Mt Pleasant St       NaN
# 23312     22828  267.4-319             1     150 Cambridgepark Dr       NaN
# 23543    184077    268B-41             1           354 Rindge Ave       NaN
# 28757    191920    188-146             1     30-32 Whittemore Ave       NaN
# 28758    191921    188-147             1     24-26 Whittemore Ave       NaN
# 28759    191922    188-148             1     18-20 Whittemore Ave       NaN
# 28874    192471    107-133             1              7 Temple St       NaN
#
#        StateClassCode_post PropertyClass_post Zoning_post MapLot_post  \
# 656                    199         CONDO-BLDG         C-1       17-20
# 920                    199         CONDO-BLDG         C-1       22-55
# 2177                   199         CONDO-BLDG         C-1      36-185
# 3014                   199         CONDO-BLDG          IB       71-56
# 3502                  1095      MULT-RES-3FAM         C-1       78-79
# 3936                   199         CONDO-BLDG         C-1       83-25
# 5093                   199         CONDO-BLDG           C       94-89
# 7120                   199         CONDO-BLDG         C-1      109-42
# 8207                   199         CONDO-BLDG         C-1     116-119
# 10189                  199         CONDO-BLDG           C     127-152
# 10935                 1091      MULT-RES-1FAM         C-1      135-14
# 12428                  199         CONDO-BLDG          BC       152-7
# 13502                  326       EATING-ESTBL      BB-HSQ      169-82
# 15549                  199         CONDO-BLDG           B      186-27
# 16149                 1094      MULT-RES-2FAM           B       192-9
# 16549                  199         CONDO-BLDG           B      194-70
# 16773                  199         CONDO-BLDG           B      196-91
# 17369                  199         CONDO-BLDG         C-1     201-101
# 18080                  199         CONDO-BLDG         A-2      211-15
# 19588                  199         CONDO-BLDG         C-1      228-31
# 21292                  199         CONDO-BLDG           B       254-8
# 21575                  199         CONDO-BLDG         C-1      257-47
# 21725                  199         CONDO-BLDG           B      259-17
# 21892                  199         CONDO-BLDG           B      262-71
# 21925                  199         CONDO-BLDG           B      262-99
# 22473                  111       4-8-UNIT-APT          BA     146A-74
# 23189                  199         CONDO-BLDG         C-1    201.5-16
# 23204                  199         CONDO-BLDG         C-1    201.5-28
# 23312                  346         INV-OFFICE        O-2A   267.4-319
# 23543                  199         CONDO-BLDG         NaN     268B-41
# 28757                  199         CONDO-BLDG        SD-2     188-146
# 28758                  199         CONDO-BLDG        SD-2     188-147
# 28759                  199         CONDO-BLDG        SD-2     188-148
# 28874                  957     Charitable Svc         O-3    107-133E
#
#        LandArea_post  ...  Condition_OverallCondition_post  \
# 656             2115  ...                              NaN
# 920             1679  ...                              NaN
# 2177            2938  ...                              NaN
# 3014          138947  ...                              NaN
# 3502            2689  ...                          Average
# 3936            5744  ...                              NaN
# 5093            1866  ...                              NaN
# 7120            5000  ...                              NaN
# 8207            6082  ...                              NaN
# 10189           2023  ...                              NaN
# 10935           4949  ...                        Excellent
# 12428           5100  ...                              NaN
# 13502           5072  ...                             Good
# 15549           3914  ...                              NaN
# 16149           9175  ...                        Excellent
# 16549           2746  ...                              NaN
# 16773           3699  ...                              NaN
# 17369           4187  ...                              NaN
# 18080           6399  ...                              NaN
# 19588           3382  ...                              NaN
# 21292          11999  ...                              NaN
# 21575         103124  ...                              NaN
# 21725           4538  ...                              NaN
# 23312                     NA                     2
# 23543                     NA                     5
# 28757                     NA                     3
# 28758                     NA                     3
# 28759                     NA                     3
# 28874                     NA                     2
#
# [34 rows x 61 columns]

# %%
merged_condo_data = pd.merge(
        condo_conversion_data_prior, 
        condo_conversion_data_post, 
        on="Address",
        how='left'
    )
merged_condo_data
# Out:
#     PID_prior GISID_prior  BldgNum_prior                  Address Unit_prior  \
# 0         690       17-20              1           139 Charles St        NaN
# 1         958       22-55              1          21 Sciarappa St        NaN
# 2        2167      36-185              1             9 Harding St        NaN
# 3        3016       71-50              1              700 Main St        NaN
# 4        3498       78-79              1          155 Webster Ave        NaN
# 5        3891       83-25              1                15 Oak St        NaN
# 6        4996       94-89              1          99 Brookline St        NaN
# 7        6714     107-133              1              7 Temple St        NaN
# 8        6984      109-42              1          207 Prospect St        NaN
# 9        8053     116-119              1             10 Ellery St        NaN
# 10      10028     127-152              1           346 Putnam Ave        NaN
# 11      10750      135-14              1          7 Trowbridge Pl        NaN
# 12      12205       152-7              1              18 White St        NaN
# 13      13218      169-82              1             32 Church St        NaN
# 14      15279      186-27              1   2579 Massachusetts Ave        NaN
# 15      15875       192-9              1              51 Cedar St        NaN
# 16      16257      194-70              1           198 Sherman St        NaN
# 17      16472      196-91              1        12 Rindgefield St        NaN
# 18      17071     201-101              1         17 Cambridge Ter        NaN
# 19      17759      211-15              1               12 Avon Pl        NaN
# 20      19223      228-31              1            280 Walden St        NaN
# 21      20903       254-8              1         55-59 Cushing St        NaN
# 22      21159      257-47              1        676-694 Huron Ave        NaN
# 23      21305      259-17              1  133-135 Fresh Pond Pkwy        NaN
# 24      21473      262-71              1      159 Fayerweather St        NaN
# 25      21506      262-99              1             17 Copley St        NaN
# 26      22007     146A-74              1           93 Kirkland St        NaN
# 27      22689    201.5-16              1            20 Vincent St        NaN
# 28      22705    201.5-28              1     37-39 Mt Pleasant St        NaN
# 29      22828   267.4-317              1     150 Cambridgepark Dr        NaN
# 30     184077     268B-41              1           354 Rindge Ave        NaN
# 31     191920     188-146              1     30-32 Whittemore Ave        NaN
# 32     191921     188-147              1     24-26 Whittemore Ave        NaN
# 33     191922     188-148              1     18-20 Whittemore Ave        NaN
#
#     StateClassCode_prior PropertyClass_prior Zoning_prior  MapLot_prior  \
# 0                    101        SNGL-FAM-RES       ="C-1"      ="17-20"
# 1                    104         TWO-FAM-RES       ="C-1"      ="22-55"
# 2                    105        THREE-FM-RES       ="C-1"     ="36-185"
# 3                    406           HIGH-TECH        ="IB"      ="71-50"
# 4                    105        THREE-FM-RES       ="C-1"      ="78-79"
# 5                    105        THREE-FM-RES       ="C-1"      ="83-25"
# 6                    105        THREE-FM-RES         ="C"      ="94-89"
# 7                    957      Charitable Svc       ="O-3"    ="107-133"
# 8                     31        MULTIUSE-COM       ="C-1"     ="109-42"
# 9                    104         TWO-FAM-RES       ="C-1"    ="116-119"
# 10                   104         TWO-FAM-RES         ="C"    ="127-152"
# 11                   101        SNGL-FAM-RES       ="C-1"     ="135-14"
# 12                   130        RES-DEV-LAND        ="BC"      ="152-7"
# 13                   345        RETAIL-OFFIC    ="BB-HSQ"     ="169-82"
# 14                   104         TWO-FAM-RES         ="B"     ="186-27"
# 15                   104         TWO-FAM-RES         ="B"      ="192-9"
# 16                   104         TWO-FAM-RES         ="B"     ="194-70"
# 17                   104         TWO-FAM-RES         ="B"     ="196-91"
# 18                   105        THREE-FM-RES       ="C-1"    ="201-101"
# 19                   104         TWO-FAM-RES       ="A-2"     ="211-15"
# 20                   105        THREE-FM-RES       ="C-1"     ="228-31"
# 21                   101        SNGL-FAM-RES         ="B"      ="254-8"
# 22                   199          CONDO-BLDG       ="C-1"     ="257-47"
# 23                   104         TWO-FAM-RES         ="B"     ="259-17"
# 24                   104         TWO-FAM-RES         ="B"     ="262-71"
# 25                   105        THREE-FM-RES         ="B"     ="262-99"
# 26                   111        4-8-UNIT-APT        ="BA"    ="146A-74"
# 27                   105        THREE-FM-RES       ="C-1"   ="201.5-16"
# 28                   101        SNGL-FAM-RES       ="C-1"   ="201.5-28"
# 29                   346          INV-OFFICE      ="O-2A"  ="267.4-317"
# 30                   199          CONDO-BLDG          =""    ="268B-41"
# 31                   130        RES-DEV-LAND      ="SD-2"    ="188-146"
# 32                   130        RES-DEV-LAND      ="SD-2"    ="188-147"
# 33                   130        RES-DEV-LAND      ="SD-2"    ="188-148"
#
#     LandArea_prior  ...  Condition_OverallCondition_post  \
# 0             2115  ...                              NaN
# 1             1679  ...                              NaN
# 2             2938  ...                              NaN
# 3            83179  ...                              NaN
# 4             2689  ...                          Average
# 5             5744  ...                              NaN
# 6             1866  ...                              NaN
# 7            37068  ...                             Good
# 8             5000  ...                              NaN
# 9             6082  ...                              NaN
# 10            2023  ...                              NaN
# 11            4949  ...                        Excellent
# 12            5000  ...                              NaN
# 13            5072  ...                             Good
# 14            3914  ...                              NaN
# 15            9175  ...                        Excellent
# 16            2746  ...                              NaN
# 17            3699  ...                              NaN
# 18            4187  ...                              NaN
# 19            6399  ...                              NaN
# 20            3382  ...                              NaN
# 21           11999  ...                              NaN
# 22          103124  ...                              NaN
# 23            4538  ...                              NaN
# 24            3600  ...                              NaN
# 25            4746  ...                              NaN
# 26            8000  ...                        Excellent
# 27            5148  ...                              NaN
# 28            6000  ...                              NaN
# 29          201495  ...                          Average
# 30           17365  ...                              NaN
# 31            5000  ...                              NaN
# 32            5000  ...                              NaN
# 33            5000  ...                              NaN
#
#    Condition_OverallGrade_post  Parking_Open_post  Parking_Covered_post  \
# 0                          NaN                0.0                   0.0
# 1                          NaN                0.0                   0.0
# 2                          NaN                0.0                   0.0
# 3                          NaN                0.0                   0.0
# 4                      Average                2.0                   0.0
# 5                          NaN                0.0                   0.0
# 6                          NaN                0.0                   0.0
# 7                         GOOD                NaN                   NaN
# 8                          NaN                0.0                   0.0
# 9                          NaN                0.0                   0.0
# 10                         NaN                0.0                   0.0
# 11                        Good                1.0                   0.0
# 12                         NaN                0.0                   0.0
# 13                   VERY-GOOD                NaN                   NaN
# 13  PRESIDENT & FELLOWS OF HARVARD COLLEGE, C/O HA...                     NA
# 14  NICOLORO, MICHAEL & ANITA CHMILARSKI,, TRUSTEE...                     NA
# 15                                51 CEDAR STREET LLC                     NA
# 16                                     HUANG, ZHENGYU                     NA
# 17           FEMAN, SIU PIN CHIN &, JOHN WELLING WARE                     NA
# 18                              CAMBRIDGE TERRACE LLC                     NA
# 19                    AVON PLACE INVESTMENT TRUST LLC                     NA
# 20                                  GALWAY REALTY LLC                     NA
# 21                    CUSHING STREET DEVELOPMENT, LLC                     NA
# 22                            GAMBLE, LINCOLN BRADLEY                     NA
# 23                      ASHE, MATTHEW & HAZEL GARLAND                     NA
# 24  159 FAYERWEATHER ST. LLC, C/O BROADWAY REALTY ...                     NA
# 25       CITYSIDE DEVELOPMENT LLC, C/O STEPHEN BALLAS                     NA
# 26                               93 KIRKLAND ST., LLC                     NA
# 27       VON TURKOVICH, RICHARD &, MYRA VON TURKOVICH                     NA
# 28                            GRIFFIN, CHRISTOPHER J.                     NA
# 29   SPUS7 150 CAMBRIDGEPARK LP, C/O CBRE-NEW ENGLAND                     NA
# 30                                                NaN                     NA
# 31                 WHITTEMORE STREET DEVELOPMENT LLC.                     NA
# 32                 WHITTEMORE STREET DEVELOPMENT LLC.                     NA
# 33                 WHITTEMORE STREET DEVELOPMENT LLC,                     NA
#
#     num_condo_units_post
# 0                      3
# 1                      3
# 2                      4
# 3                      3
# 4                      2
# 5                      2
# 6                      4
# 7                      2
# 8                      4
# 9                      4
# 10                     3
# 11                     2
# 12                     9
# 13                     2
# 14                     3
# 15                     2
# 16                     3
# 17                     3
# 18                     4
# 19                     3
# 20                     4
# 21                     4
# 22                     3
# 23                     3
# 24                     3
# 25                     4
# 26                     2
# 27                     4
# 28                     4
# 29                     2
# 30                     5
# 31                     3
# 32                     3
# 33                     3
#
# [34 rows x 120 columns]

# %% [markdown]
# ## Above is an example, now let's write it as a function

# %%
def process_condo_conversion(data_prior, data_post, prior_year, post_year):
    # Grouping the data by address and counting the number of records for each address
    count_prior = data_prior.groupby('Address').size()
    count_post = data_post.groupby('Address').size()

    # Identifying addresses which have 1 record in the prior year and more than 1 in the post year
    condo_conversion_addresses = count_post[(count_post > 1) & (count_prior == 1)].index.tolist()

    # Filtering the datasets to include only these addresses
    condo_conversion_data_prior = data_prior[data_prior['Address'].isin(condo_conversion_addresses)]
    condo_conversion_data_post = data_post[data_post['Address'].isin(condo_conversion_addresses)]

    # Calculate the number of condo conversions based on the post data
    condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
    
    # Keep only the first entry of all duplicate addresses
    condo_conversion_data_post = condo_conversion_data_post.drop_duplicates(subset='Address', keep='first')

    # Renaming all columns for prior year data except for Address column which we will use to merge
    column_mapping = {}
    for column in condo_conversion_data_prior.columns:
        if column != 'Address':
            column_mapping[column] = column + '_prior'
    condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
    
    # Renaming all columns for post year data except for Address column which we will use to merge
    column_mapping = {}
    for column in condo_conversion_data_post.columns:
        if column != 'Address':
            column_mapping[column] = column + '_post'

    # Rename the columns using the mapping dictionary
    condo_conversion_data_post.rename(columns=column_mapping, inplace=True)

    # Merging the prior and post year datasets based on address
    merged_condo_data = pd.merge(
        condo_conversion_data_prior, 
        condo_conversion_data_post, 
        on="Address",
        how="left"
    )

    # Adding the prior_year and post_year fields
    merged_condo_data['prior_year'] = prior_year
    merged_condo_data['post_year'] = post_year

    return merged_condo_data

# %%
def process_conversions_for_years(start_year, end_year, accumulated_df=None):
    if accumulated_df is None:
        accumulated_df = pd.DataFrame()  # Initialize an empty DataFrame if not provided
    
    for year in range(start_year, end_year):
        prior_year = year
        post_year = year + 1

        # Assuming you have data_2015, data_2016, ..., data_2023 loaded or created
        prior_data = globals()[f"data_{prior_year}"]
        post_data = globals()[f"data_{post_year}"]

        result_df = process_condo_conversion(prior_data, post_data, prior_year, post_year)
        accumulated_df = pd.concat([accumulated_df, result_df], ignore_index=True)

    return accumulated_df

# Initialize an empty DataFrame to accumulate the results
accumulated_results = pd.DataFrame()

# Call the function to process condo conversions for years 2015 to 2023 and accumulate the results
accumulated_results = process_conversions_for_years(2015, 2024, accumulated_results)
# Out:
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_post['num_condo_units'] = condo_conversion_data_post.groupby('Address')['Address'].transform('count')
# /var/folders/2p/_9bbqlxj6hq5_pkt2s_prdpr0000gn/T/ipykernel_12957/1451194165.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   condo_conversion_data_prior.rename(columns=column_mapping, inplace=True)

# %%
accumulated_results
# Out:
#      PID_prior GISID_prior  BldgNum_prior          Address Unit_prior  \
# 0          690       17-20              1   139 Charles St        NaN
# 1          958       22-55              1  21 Sciarappa St        NaN
# 2         2167      36-185              1     9 Harding St        NaN
# 3         3016       71-50              1      700 Main St        NaN
# 4         3498       78-79              1  155 Webster Ave        NaN
# ..         ...         ...            ...              ...        ...
# 280      22504     267C-70              1  767 Concord Ave        NaN
# 281      22633     268A-30              1   278 Rindge Ave        NaN
# 282      22666     268B-45              1   402 Rindge Ave        NaN
# 283       3767       81-23              1  333 Webster Ave        NaN
# 284     202163       27-82              1    101 Rogers St          O
#
#      StateClassCode_prior PropertyClass_prior Zoning_prior MapLot_prior  \
# 0                     101        SNGL-FAM-RES       ="C-1"     ="17-20"
# 1                     104         TWO-FAM-RES       ="C-1"     ="22-55"
# 2                     105        THREE-FM-RES       ="C-1"    ="36-185"
# 3                     406           HIGH-TECH        ="IB"     ="71-50"
# 4                     105        THREE-FM-RES       ="C-1"     ="78-79"
# ..                    ...                 ...          ...          ...
# 280                   340          GEN-OFFICE         IB-2      267C-70
# 281                   970   Housing Authority            B      268A-30
# 282                   114      AFFORDABLE APT          C-2      268B-45
# 283                   331         AUTO-SUPPLY           BA        81-23
# 284                   340          GEN-OFFICE   PUD-4B-IA1      27-82-O
#
#      LandArea_prior  ...  Parking_Open_post Parking_Covered_post  \
# 0              2115  ...                0.0                  0.0
# 1              1679  ...                0.0                  0.0
# 2              2938  ...                0.0                  0.0
# 3             83179  ...                0.0                  0.0
# 4              2689  ...                2.0                  0.0
# ..              ...  ...                ...                  ...
# 280           49856  ...                NaN                  NaN
# 281            4561  ...                NaN                  NaN
# 282          155863  ...                0.0                  0.0
# 283            6032  ...                0.0                  0.0
# 284           37483  ...                NaN                  NaN
#
#      Parking_Garage_post  UnfinishedBasementGross_post  \
# 0                    NaN                             0
# 1                    NaN                             0
# 2                    NaN                           918
# 3                    NaN                             0
# 4                    NaN                          1112
# ..                   ...                           ...
# 280                  NaN                             0
# 281                  NaN                             0
# 282                  0.0                             0
# 283                  NaN                             0
# 284                  NaN                             0
#
#      FinishedBasementGross_post  \
# 0                         821.0
# 1                        1023.0
# 2                           0.0
# 3                           0.0
# 4                           0.0
# ..                          ...
# 280                         NaN
# 281                         NaN
# 282                         0.0
# 283                         0.0
# 284                         NaN
#
#                                            Owners_post  \
# 0                               139 CHARLES STREET LLC
# 1                                 SCIARAPPA STREET LLC
# 2                                9 HARDING STREET, LLC
# 3                             MIT 650 MAIN STREET, LLC
# 4    PACHECO, ALBERT M. & LEONTINE O. PACHECO, C/O ...
# ..                                                 ...
# 280                   WEST CAMBRIDGE SCIENCE PARK, LLC
# 281                        CAMBRIDGE HOUSING AUTHORITY
# 282                        RINDGE TOWER APARTMENT LLC,
# 283                                  CITY OF CAMBRIDGE
# 284                                  CITY OF CAMBRIDGE
#
#      PropertyTaxAmount_post num_condo_units_post prior_year  post_year
# 0                        NA                    3       2015       2016
# 1                        NA                    3       2015       2016
# 2                        NA                    4       2015       2016
# 3                        NA                    3       2015       2016
# 4                        NA                    2       2015       2016
# ..                      ...                  ...        ...        ...
# 280                 98564.0                    2       2023       2024
# 281                    -1.0                   11       2023       2024
# 282                    -1.0                    6       2023       2024
# 283                    -1.0                    2       2023       2024
# 284                    -1.0                    2       2023       2024
#
# [285 rows x 122 columns]

# %% [markdown]
# ## Connecting GISID data

# %%
import geopandas as gpd

# %%
geo_df = gpd.read_file("all_data/ASSESSING_ParcelsFY2024.geojson")

# %%
geo_df.head()
# Out:
#   POLY_TYPE  MAP  UYEAR            LOC_ID  \
# 0  PRIV_ROW    -    0.0  F_761786_2962533
# 1      None  263    0.0  F_754404_2965391
# 2      None  201    0.0  F_758048_2966643
# 3      None   26    0.0  F_768259_2959811
# 4      None   36    0.0  F_767412_2961233
#
#                                  GlobalID EditDate      ML  SOURCE  \
# 0  {1118511F-457E-4275-ACDD-1A0C3D8307F0}     None     ---  ASSESS
# 1  {135EB22F-4680-4A35-8736-A2D1E588AE61}     None  263-23  ASSESS
# 2  {318E939B-73BB-473A-B3A9-B5E3A6A8AB0B}     None  201-95  ASSESS
# 3  {728A555A-EACA-48C7-9A75-1E00CD92672D}     None   26-37  ASSESS
# 4  {7EC94D31-F4E5-4B0C-9AE7-13D946E8A754}     None  36-203  ASSESS
#
#   created_user Editor  LOT created_date PLAN_ID last_edited_date  \
# 0         None   None    -         None    None       2023-09-26
# 1         None   None   23         None    None       2023-09-26
# 2         None   None   95         None    None       2023-09-26
# 3         None   None   37         None    None       2023-09-26
# 4         None   None  203         None    None       2023-09-26
#
#   last_edited_user                                           geometry
# 0         SSWEENEY  POLYGON ((-71.10911 42.37663, -71.10912 42.376...
# 1         SSWEENEY  POLYGON ((-71.13621 42.38470, -71.13640 42.384...
# 2         SSWEENEY  POLYGON ((-71.12275 42.38791, -71.12283 42.387...
# 3         SSWEENEY  POLYGON ((-71.08510 42.36914, -71.08511 42.369...
# 4         SSWEENEY  POLYGON ((-71.08823 42.37308, -71.08825 42.372...

# %%
geo_df.columns
# Out:
# Index(['POLY_TYPE', 'MAP', 'UYEAR', 'LOC_ID', 'GlobalID', 'EditDate', 'ML',
#        'SOURCE', 'created_user', 'Editor', 'LOT', 'created_date', 'PLAN_ID',
#        'last_edited_date', 'last_edited_user', 'geometry'],
#       dtype='object')

# %%
merged_conversion_df = pd.merge(accumulated_results, 
                                geo_df, 
                                how="left", 
                                left_on="GISID_prior", 
                                right_on="ML")
merged_conversion_df
# Out:
#      PID_prior GISID_prior  BldgNum_prior          Address Unit_prior  \
# 0          690       17-20              1   139 Charles St        NaN
# 1          958       22-55              1  21 Sciarappa St        NaN
# 2         2167      36-185              1     9 Harding St        NaN
# 3         3016       71-50              1      700 Main St        NaN
# 4         3498       78-79              1  155 Webster Ave        NaN
# ..         ...         ...            ...              ...        ...
# 280      22504     267C-70              1  767 Concord Ave        NaN
# 281      22633     268A-30              1   278 Rindge Ave        NaN
# 282      22666     268B-45              1   402 Rindge Ave        NaN
# 283       3767       81-23              1  333 Webster Ave        NaN
# 284     202163       27-82              1    101 Rogers St          O
#
#      StateClassCode_prior PropertyClass_prior Zoning_prior MapLot_prior  \
# 0                     101        SNGL-FAM-RES       ="C-1"     ="17-20"
# 1                     104         TWO-FAM-RES       ="C-1"     ="22-55"
# 2                     105        THREE-FM-RES       ="C-1"    ="36-185"
# 3                     406           HIGH-TECH        ="IB"     ="71-50"
# 4                     105        THREE-FM-RES       ="C-1"     ="78-79"
# ..                    ...                 ...          ...          ...
# 280                   340          GEN-OFFICE         IB-2      267C-70
# 281                   970   Housing Authority            B      268A-30
# 282                   114      AFFORDABLE APT          C-2      268B-45
# 283                   331         AUTO-SUPPLY           BA        81-23
# 284                   340          GEN-OFFICE   PUD-4B-IA1      27-82-O
#
#      LandArea_prior  ...       ML  SOURCE  created_user  Editor  LOT  \
# 0              2115  ...    17-20  ASSESS          None    None   20
# 1              1679  ...      NaN     NaN           NaN     NaN  NaN
# 2              2938  ...   36-185  ASSESS          None     KJL  185
# 3             83179  ...      NaN     NaN           NaN     NaN  NaN
# 4              2689  ...    78-79  ASSESS          None    None   79
# ..              ...  ...      ...     ...           ...     ...  ...
# 280           49856  ...  267C-70  ASSESS          None    None   70
# 281            4561  ...      NaN     NaN           NaN     NaN  NaN
# 282          155863  ...  268B-45  ASSESS          None    None   45
# 283            6032  ...      NaN     NaN           NaN     NaN  NaN
# 284           37483  ...    27-82  ASSESS          None     SJR   82
#
#      created_date  PLAN_ID last_edited_date last_edited_user  \
# 0            None     None       2023-09-26         SSWEENEY
# 1             NaN      NaN              NaN              NaN
# 2            None     None       2023-09-26         SSWEENEY
# 3             NaN      NaN              NaN              NaN
# 4            None     None       2023-09-26         SSWEENEY
# ..            ...      ...              ...              ...
# 280          None     None       2023-09-26         SSWEENEY
# 281           NaN      NaN              NaN              NaN
# 282          None     None       2023-09-26         SSWEENEY
# 283           NaN      NaN              NaN              NaN
# 284          None     None       2023-09-26         SSWEENEY
#
#                                               geometry
# 0    POLYGON ((-71.08203 42.36803, -71.08207 42.367...
# 1                                                 None
# 2    POLYGON ((-71.09062 42.37292, -71.09063 42.372...
# 3                                                 None
# 4    POLYGON ((-71.09339 42.37031, -71.09317 42.370...
# ..                                                 ...
# 280  POLYGON ((-71.15371 42.39312, -71.15369 42.393...
# 281                                               None
# 282  POLYGON ((-71.13956 42.39393, -71.13960 42.393...
# 283                                               None
# 284  POLYGON ((-71.08233 42.36706, -71.08237 42.366...
#
# [285 rows x 138 columns]

# %%
merged_conversion_df['ML'].isna().sum()
# Out:
# 23

# %%
merged_conversion_df.to_csv("katie_condo_conversions.csv")

# %% [markdown]
# # 4. Comparing Results

# %%
grace_df = pd.read_csv('grace_condo_conversions.csv')
katie_df = pd.read_csv('katie_condo_conversions.csv')

# Check if they have the same columns
same_columns = grace_df.columns.equals(katie_df.columns)

if not same_columns:
    # List the columns that are different
    different_columns_grace = grace_df.columns.difference(katie_df.columns).tolist()
    different_columns_katie = katie_df.columns.difference(grace_df.columns).tolist()
else:
    different_columns_grace = []
    different_columns_katie = []

same_columns, different_columns_grace, different_columns_katie
# Out:
# (False,
#  ['Book/Page',
#   'Book/Page_post',
#   'Book/Page_prior',
#   'BookPage',
#   'Exterior_Occupancy',
#   'Exterior_occupancy',
#   'Exterior_occupancy_post',
#   'Exterior_occupancy_prior',
#   'Map/Lot',
#   'Map/Lot_post',
#   'Map/Lot_prior',
#   'MapLot',
#   'Owner_Address',
#   'Owner_Address2',
#   'Owner_City',
#   'Owner_CoOwnerName',
#   'Owner_CoOwnerName_post',
#   'Owner_CoOwnerName_prior',
#   'Owner_Name',
#   'Owner_Name_post',
#   'Owner_Name_prior',
#   'Owner_State',
#   'Owner_Zip',
#   'Owners',
#   'PropertyTaxAmount',
#   'num_condo_units'],
#  ['Owners_post', 'Owners_prior', 'num_condo_units_post'])

# %%
address_unique_grace = grace_df['Address'].is_unique
address_unique_katie = katie_df['Address'].is_unique

address_unique_grace, address_unique_katie
# Out:
# (True, True)

# %%
katie_df["Address"] = katie_df["Address"].str.upper()

# %%
# Convert the "Address" columns in both DataFrames to sets of unique values
addresses_in_grace = set(grace_df['Address'])
addresses_in_katie = set(katie_df['Address'])

# Find addresses that are unique to grace_df
unique_to_grace = addresses_in_grace - addresses_in_katie

# Find addresses that are unique to katie_df
unique_to_katie = addresses_in_katie - addresses_in_grace

# Print the results
if unique_to_grace:
    print("Addresses unique to grace_df:")
    for address in unique_to_grace:
        print(address)

if unique_to_katie:
    print("Addresses unique to katie_df:")
    for address in unique_to_katie:
        print(address)

if not unique_to_grace and not unique_to_katie:
    print("There are no different addresses. All addresses in both DataFrames are the same.")
# Out:
# There are no different addresses. All addresses in both DataFrames are the same.
